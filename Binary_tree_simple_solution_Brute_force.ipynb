# %% [markdown]
# <a href="https://colab.research.google.com/github/murayaAI/Data-Structures-And-Algorithms/blob/main/Binary_tree_simple_solution_Brute_force.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
